# %% [markdown]
# # Drawing Conclusions Using Groupby

# %%
# Load `winequality_edited.csv`

import pandas as pd
wine_df=pd.read_csv("winequality_edited.csv")
wine_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %% [raw]
#  Is a certain type of wine associated with higher quality?

# %%
# Find the mean quality of each wine type (red and white) with groupby
wine_df.groupby(wine_df['color']=='red').mean()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# color
# False       6.854788          0.278241     0.334192        6.391415
# True        8.319637          0.527821     0.270976        2.538806
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# color
# False   0.045772            35.308085            138.360657  0.994027
# True    0.087467            15.874922             46.467792  0.996747
#
#              pH  sulphates    alcohol   quality
# color
# False  3.188267   0.489847  10.514267  5.877909
# True   3.311113   0.658149  10.422983  5.636023

# %%
wine_df.groupby(wine_df['color']=='white').mean()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# color
# False       8.319637          0.527821     0.270976        2.538806
# True        6.854788          0.278241     0.334192        6.391415
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide   density  \
# color
# False   0.087467            15.874922             46.467792  0.996747
# True    0.045772            35.308085            138.360657  0.994027
#
#              pH  sulphates    alcohol   quality
# color
# False  3.311113   0.658149  10.422983  5.636023
# True   3.188267   0.489847  10.514267  5.877909

# %% [markdown]
# ### What level of acidity receives the highest average rating?

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas describe
wine_df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [0,25,50,75,100] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = ['High' ,'Moderately High' ,'Medium','Low' ] # Name each acidity level category

# %%
# Creates acidity_levels column
wine_df['acidity_levels'] = pd.cut(wine_df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
#wine_df.head()

# %%
# Find the mean quality of each acidity level with groupby
wine_df.groupby('acidity_levels').mean()
# Out:
#                  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# acidity_levels
# High                  7.215307          0.339666     0.318633        5.443235
# Moderately High            NaN               NaN          NaN             NaN
# Medium                     NaN               NaN          NaN             NaN
# Low                        NaN               NaN          NaN             NaN
#
#                  chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# acidity_levels
# High              0.056034            30.525319            115.744574
# Moderately High        NaN                  NaN                   NaN
# Medium                 NaN                  NaN                   NaN
# Low                    NaN                  NaN                   NaN
#
#                   density        pH  sulphates    alcohol   quality
# acidity_levels
# High             0.994697  3.218501   0.531268  10.491801  5.818378
# ...

# %%
# Save changes for the next section
wine_df.to_csv('winequality_edited.csv', index=False)
